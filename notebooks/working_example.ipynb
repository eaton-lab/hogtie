# %% [markdown]
# # Working Example for Hogtie

# %%
import hogtie
import pandas as pd
import toytree
import numpy as np

# %% [markdown]
# ## Run hogtie on provided sample matrix and tree

# %%
import os
HOGTIEDIR = os.path.dirname(os.getcwd())
file1 = os.path.join(HOGTIEDIR, "sampledata", "testmatrix.csv")
file2 = os.path.join(HOGTIEDIR, "sampledata", "testtree.txt")

# %%
testmatrix = hogtie.MatrixParser(tree=file2, matrix=file1, model='ARD')
testmatrix.matrix_likelihoods()
# Out:
# 04:03 | INFO    | optimize        | {'alpha': 1.527873, 'beta': 2.117664, 'Lik': -0.001325, 'negLogLik': 6.63, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 1.197345, 'beta': 0.564985, 'Lik': -0.001884, 'negLogLik': 6.27, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 8.315613, 'beta': 5.491408, 'Lik': -0.00119, 'negLogLik': 6.73, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 26.603758, 'beta': 6.650525, 'Lik': -0.006711, 'negLogLik': 5.0, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 7.303364, 'beta': 4.935767, 'Lik': -0.001185, 'negLogLik': 6.74, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.940945, 'beta': 4.940011, 'Lik': -0.000957, 'negLogLik': 6.95, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 6.945515, 'beta': 4.599964, 'Lik': -0.001182, 'negLogLik': 6.74, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.484828, 'beta': 1.954518, 'Lik': -0.00226, 'negLogLik': 6.09, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 2.913163, 'beta': 0.747845, 'Lik': -0.007086, 'negLogLik': 4.95, 'convergence': True}

# %%
testmatrix.likelihoods
# Out:
#       0
# 0  6.63
# 1  6.27
# 2  6.73
# 3  5.00
# 4  6.74
# 5  6.95
# 6  6.74
# 7  6.09
# 8  4.95
# 9  4.95

# %%
testmatrix.genome_graph()
# Out:
# (<toyplot.canvas.Canvas at 0x7f934e6bcb80>,
#  <toyplot.coordinates.Cartesian at 0x7f934e73f250>,
#  <toyplot.mark.Plot at 0x7f934f062580>)
# <div class="toyplot" id="t615483c514ee4e1b849df5270b59a948" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="500.0px" height="500.0px" viewBox="0 0 500.0 500.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t1814eeefe5e74821b6ff607e62e3b042"><g class="toyplot-coordinates-Cartesian" id="t7304f1fd21624657a1a88e43baa14eb1"><clipPath id="t5195d942216a4303b5bb8cb10d2f1a79"><rect x="40.0" y="40.0" width="420.0" height="420.0"></rect></clipPath><g clip-path="url(#t5195d942216a4303b5bb8cb10d2f1a79)"><g class="toyplot-mark-Plot" style="fill:none" id="te644d2684811421eb07ef85c68f9ff8b"><g class="toyplot-Series"><path d="M 450.0 241.46084625694013" style="stroke:rgb(0%,0%,100%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g></g><g class="toyplot-coordinates-Axis" id="tbaa27e3ddcdb484d861cb9374d744b79" transform="translate(50.0,450.0)translate(0,10.0)"><line x1="0" y1="0" x2="400.0" y2="0" style=""></line><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(133.33333333333331,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">3</text></g><g transform="translate(266.66666666666663,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6</text></g><g transform="translate(400.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">9</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g><g class="toyplot-coordinates-Axis" id="t2beca67751bd4f62843f3fab63da6702" transform="translate(50.0,450.0)rotate(-90.0)translate(0,-10.0)"><line x1="208.53915374305987" y1="0" x2="208.53915374305987" y2="0" style=""></line><g><g transform="translate(0.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">5.8</text></g><g transform="translate(95.73042312847006,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6.0</text></g><g transform="translate(191.46084625694013,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6.2</text></g><g transform="translate(287.19126938541024,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6.5</text></g><g transform="translate(382.92169251388026,-6)"><text x ...
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.length; ++j)
#                   {
#                     if(j)
#                       csv += ",";
#                     csv += table.columns[j][i];
#                   }
#                   csv += "\n";
#                 }
#                 return csv;
#             }
#         }
#
#         return module;
#     })();
# modules["toyplot/root/id"] = "t615483c514ee4e1b849df5270b59a948";
# modules["toyplot/root"] = (function(root_id)
#     {
#         return document.querySelector("#" + root_id);
#     })(modules["toyplot/root/id"]);
# modules["toyplot/canvas/id"] = "t1814eeefe5e74821b6ff607e62e3b042";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot/menus/context"] = (function(root, canvas)
#     {
#         var wrapper = document.createElement("div");
#         wrapper.innerHTML = "<ul class='toyplot-context-menu' style='background:#eee; border:1px solid #b8b8b8; border-radius:5px; box-shadow: 0px 0px 8px rgba(0%,0%,0%,0.25); margin:0; padding:3px 0; position:fixed; visibility:hidden;'></ul>"
#         var menu = wrapper.firstChild;
#
#         root.appendChild(menu);
#
#         var items = [];
#
#         var ignore_mouseup = null;
#         function open_menu(e)
#         {
#             var show_menu = false;
#             for(var index=0; index != items.length; ++index)
#             {
#                 var item = items[index];
#                 if(item.show(e))
#                 {
#                     item.item.style.display = "block";
#                     show_menu = true;
#                 }
#                 else
#                 {
#                     item.item.style.display = "none";
#                 }
#             }
#
#             if(show_menu)
#             {
#                 ignore_mouseup = true;
#                 menu.style.left = (e.clientX + 1) + "px";
#                 menu.style.top = (e.clientY - 5) + "px";
#                 menu.style.visibility = "visible";
#                 e.stopPropagation();
#                 e.preventDefault();
#             }
#         }
#
#         function close_menu()
#         {
#             menu.style.visibility = "hidden";
#         }
#
#         function contextmenu(e)
#         {
#             open_menu(e);
#         }
#
#         function mousemove(e)
#         {
#             ignore_mouseup = false;
#         }

# %%
test = hogtie.SimulateExpectations(tree=file2,model='ARD')

# %%
test.create_null()
# Out:
# 04:03 | INFO    | optimize        | {'alpha': 0.28178, 'beta': 2.741809, 'Lik': -0.040682, 'negLogLik': 3.2, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 0.423152, 'beta': 3.863305, 'Lik': -0.039463, 'negLogLik': 3.23, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.012498, 'beta': 36.127956, 'Lik': -0.038742, 'negLogLik': 3.25, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 0.394349, 'beta': 3.625973, 'Lik': -0.039633, 'negLogLik': 3.23, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 0.394349, 'beta': 3.625973, 'Lik': -0.039633, 'negLogLik': 3.23, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 1.044227, 'beta': 4.107114, 'Lik': -0.006838, 'negLogLik': 4.99, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 5.555288, 'beta': 50.0, 'Lik': -0.038742, 'negLogLik': 3.25, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 0.855893, 'beta': 7.678349, 'Lik': -0.03881, 'negLogLik': 3.25, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 1.97205, 'beta': 4.52908, 'Lik': -0.002258, 'negLogLik': 6.09, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 1.506723, 'beta': 2.196699, 'Lik': -0.00131, 'negLogLik': 6.64, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 2.594291, 'beta': 23.360199, 'Lik': -0.038741, 'negLogLik': 3.25, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.365593, 'beta': 17.39894, 'Lik': -0.00671, 'negLogLik': 5.0, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 2.594291, 'beta': 23.360199, 'Lik': -0.038741, 'negLogLik': 3.25, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.024011, 'beta': 9.367673, 'Lik': -0.002213, 'negLogLik': 6.11, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 6.580622, 'beta': 9.661182, 'Lik': -0.001192, 'negLogLik': 6.73, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 1.524912, 'beta': 1.638355, 'Lik': -0.001152, 'negLogLik': 6.77, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 3.008409, 'beta': 2.08298, 'Lik': -0.001243, 'negLogLik': 6.69, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 2.196674, 'beta': 1.50671, 'Lik': -0.00131, 'negLogLik': 6.64, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.529071, 'beta': 1.972046, 'Lik': -0.002258, 'negLogLik': 6.09, 'convergence': True}
# 04:03 | INFO    | optimize        | {'alpha': 4.107094, 'beta': 1.044222, 'Lik': -0.006838, 'negLogLik': 4.99, 'convergence': True}

# %%
test.zscores
# Out:
# array([[-1.18847576],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [-1.16822048],
#        [ 0.02008925],
#        [ 0.02008925],
#        [ 0.02008925],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [-1.15471696],
#        [ 0.02684101],
#        [ 0.02684101],
#        [ 0.02684101],
#        [-1.15471696],
#        [ 0.77628636],
#        [ 0.77628636],
#        [ 0.77628636],
#        [ 0.77628636],
#        [ 0.77628636],
#        [ 1.19489547],
#        [ 1.22190251],
#        [ 1.22190251],
#        [ 1.22190251],
#        [ 1.22190251],
#        [ 1.16788843],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 1.13412963],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.76278284],
#        [ 0.02008925],
#        [ 0.02008925]])
